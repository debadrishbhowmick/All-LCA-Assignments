# %%
list = [1,2,3,4,5]
list.append(6)
print(list)
list.insert(1,9)
print(list)
list.remove(3)
print(list)
list.pop(5)
print(list)
list.sort()
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 9, 2, 3, 4, 5, 6]
# [1, 9, 2, 4, 5, 6]
# [1, 9, 2, 4, 5]
# [1, 2, 4, 5, 9]

# %%
tup = (1,2,3,4,5,2,9)
print(tup.count(2))
print(tup.index(9))
# Out:
# 2
# 6

# %%
dict = {
    'a':1,
    'b':2,
    'c':3
}
dict['d']=4
print(dict)
print(dict.keys())
print(dict.values())
print(dict.items())
del dict['b']
print(dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# dict_keys(['a', 'b', 'c', 'd'])
# dict_values([1, 2, 3, 4])
# dict_items([('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# {'a': 1, 'c': 3, 'd': 4}
