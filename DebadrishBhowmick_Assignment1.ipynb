# %%
list = [1,2,3,4,5]
list.append(6)
print(list)
list.insert(1,9)
print(list)
list.remove(3)
print(list)
list.pop(5)
print(list)
list.sort()
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 9, 2, 3, 4, 5, 6]
# [1, 9, 2, 4, 5, 6]
# [1, 9, 2, 4, 5]
# [1, 2, 4, 5, 9]

# %%
tup = (1,2,3,4,5,2,9)
print(tup.count(2))
print(tup.index(9))
# Out:
# 2
# 6

# %%
dict = {
    'a':1,
    'b':2,
    'c':3
}
dict ['b']=7
print(dict)
dict['d']=4
print(dict)
dict.pop('a')
print(dict)
# Out:
# {'a': 1, 'b': 7, 'c': 3}
# {'a': 1, 'b': 7, 'c': 3, 'd': 4}
# {'b': 7, 'c': 3, 'd': 4}
