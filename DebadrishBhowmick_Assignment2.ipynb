# %%
a = float(input("num1: "))
b = float(input("num2: "))
c = float(input("num3: "))

if a>b and a>c:
    print("a is largest")
elif b>a and b>c:
    print("b is largest")
else:
    print("c is largest")
